# %%
# !pip install selenium
# Out:
# ...
#   Using cached selenium-3.3.1-py2.py3-none-any.whl
# ...

# %%
# California, New York, Florida, Texas, Michigan
# Summer - 1. California, 2. Texas, 3. Florida, 4. Alabama, 5. Utah, 6. Arizona, 7. Nevada
# Winter - 1. New York, 2. Washington DC, 3. Michigan, 4. Wisconsin, 5. Massachusetts, 6. Minnesota 7.Ohio
# Spring - 1. California, 2. Texas, 3. Louisiana 4. Maryland 5. Virginia, 6. Oregon, 7. South Carolina
# Fall - 1. Virginia, 2. Vermont 3. Tennessee 4. California 5.New York 6. New Hampshire 7.Colorado

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib2

# %%
# searchterms_list = ['summer','summer California', 'summer Texas', 'summer Florida', 'summer Alabama', 'summer Utah',
#                     'summer Arizona','summer Nevada','winter new york', 'winter washington', 'winter michigan',
#                    'winter wisconsin', 'winter massachusetts','winter minnesota','winter ohio','spring california',
#                     'spring texas','spring louisiana','spring maryland','spring virginia','spring oregon','spring north carolina',
#                     'fall virginia','fall vermont','fall tennessee','fall california','fall new york','fall new hampshire',
#                     'fall colorado','fall','winter','spring']

# %%
searchterm = 'fall season'

# %%
# def download_images(searchterm):
browser = webdriver.Firefox()
url = "https://www.google.com/search?q="+searchterm+"&source=lnm&tbm=isch"
browser.get(url)
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
counter = 0
succounter = 0

if not os.path.exists(searchterm):
    os.mkdir(searchterm)

for _ in range(500):
    browser.execute_script("window.scrollBy(0,10000)")

print "Images to download"    
print len(browser.find_elements_by_xpath("//div[@class='rg_meta']"))

for x in browser.find_elements_by_xpath("//div[@class='rg_meta']"):
    counter = counter + 1
    print "Total Count:", counter
    print "Succsessful Count:", succounter
    print "URL:",json.loads(x.get_attribute('innerHTML'))["ou"]

    img = json.loads(x.get_attribute('innerHTML'))["ou"]
    imgtype = json.loads(x.get_attribute('innerHTML'))["ity"]
    try:
        req = urllib2.Request(img, headers={'User-Agent': header})
        raw_img = urllib2.urlopen(req).read()
        File = open(os.path.join(searchterm , searchterm + "_" + str(counter) + "." + imgtype), "wb")
        File.write(raw_img)
        File.close()
        succounter = succounter + 1
    except:
            print "can't get img"

print succounter, "pictures succesfully downloaded"
browser.close()
# Out:
# Images to download
# 400
# Total Count: 1
# Succsessful Count: 0
# URL: http://az616578.vo.msecnd.net/files/2016/09/24/636102838626708109696403224_Fall.jpg
# Total Count: 2
# Succsessful Count: 1
# URL: http://www.feelguide.com/wp-content/uploads/2013/09/FallSeason.jpg?w=240
# Total Count: 3
# Succsessful Count: 2
# URL: http://az616578.vo.msecnd.net/files/2015/09/13/6357777466999070151110713026_fall.imgopt1000x70.jpg
# Total Count: 4
# Succsessful Count: 3
# URL: http://az616578.vo.msecnd.net/files/2015/09/28/635790614985646319-795593121_6357881043110928541597602119_fall%2520leaves.imgopt1000x70.jpg
# Total Count: 5
# Succsessful Count: 4
# URL: http://www.almanac.com/sites/default/files/image_nodes/fall-1072821_1920.jpg
# Total Count: 6
# Succsessful Count: 5
# URL: http://kingofwallpapers.com/fall-season-backgrounds/fall-season-backgrounds-004.jpg
# Total Count: 7
# Succsessful Count: 6
# URL: http://wallpapercave.com/wp/J7pndV0.jpg
# Total Count: 8
# Succsessful Count: 7
# ...

# %%
# searchterm = 'summer california'
# url = "https://www.google.com/search?q="+searchterm+"&source=lnm&tbm=isch"

# %%
# browser = webdriver.Firefox()

# %%
# download_images('summer')

# %%
# browser.get(url)
# header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
# counter = 0
# succounter = 0

# %%
# Out:
# Images to download
# 400
# Total Count: 1
# Succsessful Count: 0
# URL: https://az616578.vo.msecnd.net/files/responsive/cover/main/desktop/2015/04/28/635658537503804801-214745813_bridal-showplace-california-summer-weddings.imgopt1000x70.jpg
# Total Count: 2
# Succsessful Count: 1
# URL: http://www.lovethispic.com/uploaded_images/20959-California-Summer.jpg
# Total Count: 3
# Succsessful Count: 2
# URL: http://joangable.com/wp-content/uploads/2013/09/dreamin.jpg
# Total Count: 4
# Succsessful Count: 3
# URL: http://www.eagleadventuretours.de/wp-content/uploads/2013/10/EAT_MC-California-Endless-Summer-61.jpg?5e6482
# Total Count: 5
# Succsessful Count: 4
# URL: https://media.timeout.com/images/102442053/image.jpg
# Total Count: 6
# Succsessful Count: 5
# URL: http://indietravel.net/wp-content/uploads/2015/08/California-Travel-Tip.jpg
# Total Count: 7
# Succsessful Count: 6
# ...

# %%
# Out:
# first 10 results from bing [ { url: 'http://www.hangthebankers.com/wp-content/uploads/2012/08/Banana-1024x679.jpg',
